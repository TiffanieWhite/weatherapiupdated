# %%
import requests
import pandas as pd
from datetime import datetime

# %%
api_key = "a76201b1111a476d9dd14839250709"
baseurl = "http://api.weatherapi.com/v1/"
#f"http://api.weatherapi.com/v1/current.json?key={api_key}&q={city}"
city="Louisville"

# %%
response = requests.get(f"http://api.weatherapi.com/v1/current.json?key={api_key}&q={city}")
response.status_code
# Out:
# 200

# %%
data = response.json()
data ['current']
# Out:
# {'last_updated_epoch': 1757332800,
#  'last_updated': '2025-09-08 08:00',
#  'temp_c': 10.6,
#  'temp_f': 51.1,
#  'is_day': 1,
#  'condition': {'text': 'Sunny',
#   'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#   'code': 1000},
#  'wind_mph': 3.8,
#  'wind_kph': 6.1,
#  'wind_degree': 36,
#  'wind_dir': 'NE',
#  'pressure_mb': 1025.0,
#  'pressure_in': 30.28,
#  'precip_mm': 0.0,
#  'precip_in': 0.0,
#  'humidity': 83,
#  'cloud': 0,
#  'feelslike_c': 10.1,
#  'feelslike_f': 50.2,
#  'windchill_c': 12.0,
#  'windchill_f': 53.7,
#  'heatindex_c': 12.5,
#  'heatindex_f': 54.5,
#  'dewpoint_c': 6.9,
#  'dewpoint_f': 44.4,
#  'vis_km': 16.0,
#  'vis_miles': 9.0,
#  'uv': 0.1,
#  'gust_mph': 7.3,
#  'gust_kph': 11.8,
#  'short_rad': 3.09,
#  'diff_rad': 1.34,
#  'dni': 2.28,
#  'gti': 1.96}

# %%
forecast_url = f"{baseurl}forecast.json?key={api_key}&q={city}&days=3"
forecast_response =requests.get(forecast_url)
forecast_response.status_code
# Out:
# 200

# %%
forecast_data = forecast_response.json()
forecast = forecast_data['forecast']['forecastday']
forecast
# Out:
# [{'date': '2025-09-08',
#   'date_epoch': 1757289600,
#   'day': {'maxtemp_c': 26.2,
#    'maxtemp_f': 79.2,
#    'mintemp_c': 10.9,
#    'mintemp_f': 51.6,
#    'avgtemp_c': 18.6,
#    'avgtemp_f': 65.6,
#    'maxwind_mph': 5.4,
#    'maxwind_kph': 8.6,
#    'totalprecip_mm': 0.0,
#    'totalprecip_in': 0.0,
#    'totalsnow_cm': 0.0,
#    'avgvis_km': 10.0,
#    'avgvis_miles': 6.0,
#    'avghumidity': 54,
#    'daily_will_it_rain': 0,
#    'daily_chance_of_rain': 0,
#    'daily_will_it_snow': 0,
#    'daily_chance_of_snow': 0,
#    'condition': {'text': 'Sunny',
#     'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#     'code': 1000},
#    'uv': 1.6},
#   'astro': {'sunrise': '07:19 AM',
#    'sunset': '08:01 PM',
#    'moonrise': '08:33 PM',
#    'moonset': '08:13 AM',
#    'moon_phase': 'Waning Gibbous',
#    'moon_illumination': 100,
#    'is_moon_up': 1,
#    'is_sun_up': 0},
#   'hour': [{'time_epoch': 1757304000,
#     'time': '2025-09-08 00:00',
#     'temp_c': 15.8,
#     'temp_f': 60.5,
#     'is_day': 0,
#     'condition': {'text': 'Clear ',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#      'code': 1000},
#     'wind_mph': 5.1,
#     'wind_kph': 8.3,
#     'wind_degree': 14,
#     'wind_dir': 'NNE',
#     'pressure_mb': 1024.0,
#     'pressure_in': 30.24,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 59,
#     'cloud': 0,
#     'feelslike_c': 15.8,
#     'feelslike_f': 60.4,
#     'windchill_c': 15.8,
#     'windchill_f': 60.4,
#     'heatindex_c': 15.8,
#     'heatindex_f': 60.5,
#     'dewpoint_c': 7.8,
#     'dewpoint_f': 46.0,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 10.8,
#     'gust_kph': 17.4,
#     'uv': 0,
#     'short_rad': 0,
#     'diff_rad': 0,
#     'dni': 0,
#     'gti': 0},
#    {'time_epoch': 1757307600,
#     'time': '2025-09-08 01:00',
#     'temp_c': 15.0,
#     'temp_f': 58.9,
#     'is_day': 0,
#     'condition': {'text': 'Clear ',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#      'code': 1000},
#     'wind_mph': 5.1,
#     'wind_kph': 8.3,
#     'wind_degree': 16,
#     'wind_dir': 'NNE',
#     'pressure_mb': 1024.0,
#     'pressure_in': 30.24,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 62,
#     'cloud': 0,
#     'feelslike_c': 14.9,
#     'feelslike_f': 58.8,
#     'windchill_c': 14.9,
#     'windchill_f': 58.8,
#     'heatindex_c': 15.0,
#     'heatindex_f': 58.9,
#     'dewpoint_c': 7.7,
#     'dewpoint_f': 45.8,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 10.8,
#     'gust_kph': 17.4,
#     'uv': 0,
#     'short_rad': 0,
#     'diff_rad': 0,
#     'dni': 0,
#     'gti': 0},
#    {'time_epoch': 1757311200,
#     'time': '2025-09-08 02:00',
#     'temp_c': 14.2,
#     'temp_f': 57.5,
#     'is_day': 0,
#     'condition': {'text': 'Clear ',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#      'code': 1000},
#     'wind_mph': 4.9,
#     'wind_kph': 7.9,
#     'wind_degree': 20,
#     'wind_dir': 'NNE',
#     'pressure_mb': 1024.0,
#     'pressure_in': 30.25,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 64,
#     'cloud': 0,
#     'feelslike_c': 14.0,
#     'feelslike_f': 57.2,
#     'windchill_c': 14.0,
#     'windchill_f': 57.2,
#     'heatindex_c': 14.2,
#     'heatindex_f': 57.5,
#     'dewpoint_c': 7.5,
#     'dewpoint_f': 45.5,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 10.3,
#     'gust_kph': 16.6,
#     'uv': 0,
#     'short_rad': 0,
#     'diff_rad': 0,
#     'dni': 0,
#     'gti': 0},
#    {'time_epoch': 1757314800,
#     'time': '2025-09-08 03:00',
#     'temp_c': 13.4,
#     'temp_f': 56.2,
#     'is_day': 0,
#     'condition': {'text': 'Clear ',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#      'code': 1000},
#     'wind_mph': 4.5,
#     'wind_kph': 7.2,
#     'wind_degree': 28,
#     'wind_dir': 'NNE',
#     'pressure_mb': 1025.0,
#     'pressure_in': 30.26,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 67,
#     'cloud': 0,
#     'feelslike_c': 13.2,
#     'feelslike_f': 55.7,
#     'windchill_c': 13.2,
#     'windchill_f': 55.7,
#     'heatindex_c': 13.4,
#     'heatindex_f': 56.2,
#     'dewpoint_c': 7.4,
#     'dewpoint_f': 45.4,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 9.4,
#     'gust_kph': 15.1,
#     'uv': 0,
#     'short_rad': 0,
#     'diff_rad': 0,
#     'dni': 0,
#     'gti': 0},
#    {'time_epoch': 1757318400,
#     'time': '2025-09-08 04:00',
#     'temp_c': 12.8,
#     'temp_f': 55.0,
#     'is_day': 0,
#     'condition': {'text': 'Clear ',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#      'code': 1000},
#     'wind_mph': 4.3,
#     'wind_kph': 6.8,
#     'wind_degree': 24,
#     'wind_dir': 'NNE',
#     'pressure_mb': 1025.0,
#     'pressure_in': 30.27,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 70,
#     'cloud': 0,
#     'feelslike_c': 12.4,
#     'feelslike_f': 54.3,
#     'windchill_c': 12.4,
#     'windchill_f': 54.3,
#     'heatindex_c': 12.8,
#     'heatindex_f': 55.0,
#     'dewpoint_c': 7.3,
#     'dewpoint_f': 45.2,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 8.9,
#     'gust_kph': 14.4,
#     'uv': 0,
#     'short_rad': 0,
#     'diff_rad': 0,
#     'dni': 0,
#     'gti': 0},
#    {'time_epoch': 1757322000,
#     'time': '2025-09-08 05:00',
#     'temp_c': 12.1,
#     'temp_f': 53.8,
#     'is_day': 0,
#     'condition': {'text': 'Clear ',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#      'code': 1000},
#     'wind_mph': 4.5,
#     'wind_kph': 7.2,
#     'wind_degree': 27,
#     'wind_dir': 'NNE',
#     'pressure_mb': 1025.0,
#     'pressure_in': 30.27,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 72,
#     'cloud': 0,
#     'feelslike_c': 11.7,
#     'feelslike_f': 53.0,
#     'windchill_c': 11.7,
#     'windchill_f': 53.0,
#     'heatindex_c': 12.1,
#     'heatindex_f': 53.8,
#     'dewpoint_c': 7.2,
#     'dewpoint_f': 44.9,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 9.4,
#     'gust_kph': 15.1,
#     'uv': 0,
#     'short_rad': 0,
#     'diff_rad': 0,
#     'dni': 0,
#     'gti': 0},
#    {'time_epoch': 1757325600,
#     'time': '2025-09-08 06:00',
#     'temp_c': 11.5,
#     'temp_f': 52.7,
#     'is_day': 0,
#     'condition': {'text': 'Clear ',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#      'code': 1000},
#     'wind_mph': 4.7,
#     'wind_kph': 7.6,
#     'wind_degree': 26,
#     'wind_dir': 'NNE',
#     'pressure_mb': 1025.0,
#     'pressure_in': 30.28,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 74,
#     'cloud': 0,
#     'feelslike_c': 10.9,
#     'feelslike_f': 51.7,
#     'windchill_c': 10.9,
#     'windchill_f': 51.7,
#     'heatindex_c': 11.5,
#     'heatindex_f': 52.7,
#     'dewpoint_c': 7.1,
#     'dewpoint_f': 44.7,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 9.6,
#     'gust_kph': 15.5,
#     'uv': 0,
#     'short_rad': 0,
#     'diff_rad': 0,
#     'dni': 0,
#     'gti': 0},
#    {'time_epoch': 1757329200,
#     'time': '2025-09-08 07:00',
#     'temp_c': 11.3,
#     'temp_f': 52.3,
#     'is_day': 0,
#     'condition': {'text': 'Clear ',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#      'code': 1000},
#     'wind_mph': 4.3,
#     'wind_kph': 6.8,
#     'wind_degree': 31,
#     'wind_dir': 'NNE',
#     'pressure_mb': 1026.0,
#     'pressure_in': 30.3,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 77,
#     'cloud': 0,
#     'feelslike_c': 10.6,
#     'feelslike_f': 51.2,
#     'windchill_c': 10.6,
#     'windchill_f': 51.2,
#     'heatindex_c': 11.3,
#     'heatindex_f': 52.3,
#     'dewpoint_c': 7.0,
#     'dewpoint_f': 44.6,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 8.8,
#     'gust_kph': 14.1,
#     'uv': 0,
#     'short_rad': 0,
#     'diff_rad': 0,
#     'dni': 0,
#     'gti': 0},
#    {'time_epoch': 1757332800,
#     'time': '2025-09-08 08:00',
#     'temp_c': 10.6,
#     'temp_f': 51.1,
#     'is_day': 1,
#     'condition': {'text': 'Sunny',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#      'code': 1000},
#     'wind_mph': 3.8,
#     'wind_kph': 6.1,
#     'wind_degree': 36,
#     'wind_dir': 'NE',
#     'pressure_mb': 1025.0,
#     'pressure_in': 30.28,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 83,
#     'cloud': 0,
#     'feelslike_c': 12.0,
#     'feelslike_f': 53.7,
#     'windchill_c': 12.0,
#     'windchill_f': 53.7,
#     'heatindex_c': 12.5,
#     'heatindex_f': 54.5,
#     'dewpoint_c': 6.9,
#     'dewpoint_f': 44.4,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 16.0,
#     'vis_miles': 9.0,
#     'gust_mph': 7.3,
#     'gust_kph': 11.8,
#     'uv': 0.1,
#     'short_rad': 3.09,
#     'diff_rad': 1.34,
#     'dni': 2.28,
#     'gti': 1.96},
#    {'time_epoch': 1757336400,
#     'time': '2025-09-08 09:00',
#     'temp_c': 14.9,
#     'temp_f': 58.9,
#     'is_day': 1,
#     'condition': {'text': 'Sunny',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#      'code': 1000},
#     'wind_mph': 4.7,
#     'wind_kph': 7.6,
#     'wind_degree': 57,
#     'wind_dir': 'ENE',
#     'pressure_mb': 1026.0,
#     'pressure_in': 30.3,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 65,
#     'cloud': 0,
#     'feelslike_c': 14.7,
#     'feelslike_f': 58.5,
#     'windchill_c': 14.7,
#     'windchill_f': 58.5,
#     'heatindex_c': 14.9,
#     'heatindex_f': 58.9,
#     'dewpoint_c': 7.3,
#     'dewpoint_f': 45.1,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 6.2,
#     'gust_kph': 9.9,
#     'uv': 0.7,
#     'short_rad': 174.46,
#     'diff_rad': 48.31,
#     'dni': 152.27,
#     'gti': 95.79},
#    {'time_epoch': 1757340000,
#     'time': '2025-09-08 10:00',
#     'temp_c': 18.3,
#     'temp_f': 64.9,
#     'is_day': 1,
#     'condition': {'text': 'Sunny',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#      'code': 1000},
#     'wind_mph': 5.1,
#     'wind_kph': 8.3,
#     'wind_degree': 57,
#     'wind_dir': 'ENE',
#     'pressure_mb': 1026.0,
#     'pressure_in': 30.3,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 55,
#     'cloud': 0,
#     'feelslike_c': 18.2,
#     'feelslike_f': 64.7,
#     'windchill_c': 18.2,
#     'windchill_f': 64.7,
#     'heatindex_c': 19.6,
#     'heatindex_f': 67.2,
#     'dewpoint_c': 8.2,
#     'dewpoint_f': 46.8,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 5.9,
#     'gust_kph': 9.5,
#     'uv': 1.9,
#     'short_rad': 278.0,
#     'diff_rad': 60.78,
#     'dni': 259.29,
#     'gti': 144.19},
#    {'time_epoch': 1757343600,
#     'time': '2025-09-08 11:00',
#     'temp_c': 20.5,
#     'temp_f': 68.9,
#     'is_day': 1,
#     'condition': {'text': 'Sunny',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#      'code': 1000},
#     'wind_mph': 5.4,
#     'wind_kph': 8.6,
#     'wind_degree': 67,
#     'wind_dir': 'ENE',
#     'pressure_mb': 1026.0,
#     'pressure_in': 30.3,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 45,
#     'cloud': 0,
#     'feelslike_c': 20.4,
#     'feelslike_f': 68.8,
#     'windchill_c': 20.4,
#     'windchill_f': 68.8,
#     'heatindex_c': 21.8,
#     'heatindex_f': 71.3,
#     'dewpoint_c': 9.4,
#     'dewpoint_f': 48.8,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 6.2,
#     'gust_kph': 9.9,
#     'uv': 3.7,
#     'short_rad': 376.42,
#     'diff_rad': 69.76,
#     'dni': 386.24,
#     'gti': 190.32},
#    {'time_epoch': 1757347200,
#     'time': '2025-09-08 12:00',
#     'temp_c': 22.2,
#     'temp_f': 71.9,
#     'is_day': 1,
#     'condition': {'text': 'Sunny',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#      'code': 1000},
#     'wind_mph': 5.4,
#     'wind_kph': 8.6,
#     'wind_degree': 73,
#     'wind_dir': 'ENE',
#     'pressure_mb': 1025.0,
#     'pressure_in': 30.28,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 38,
#     'cloud': 0,
#     'feelslike_c': 23.2,
#     'feelslike_f': 73.7,
#     'windchill_c': 22.2,
#     'windchill_f': 71.9,
#     'heatindex_c': 23.2,
#     'heatindex_f': 73.7,
#     'dewpoint_c': 7.6,
#     'dewpoint_f': 45.8,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 6.2,
#     'gust_kph': 9.9,
#     'uv': 5.4,
#     'short_rad': 464.24,
#     'diff_rad': 76.34,
#     'dni': 554.12,
#     'gti': 234.64},
#    {'time_epoch': 1757350800,
#     'time': '2025-09-08 13:00',
#     'temp_c': 23.8,
#     'temp_f': 74.8,
#     'is_day': 1,
#     'condition': {'text': 'Sunny',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#      'code': 1000},
#     'wind_mph': 5.1,
#     'wind_kph': 8.3,
#     'wind_degree': 76,
#     'wind_dir': 'ENE',
#     'pressure_mb': 1025.0,
#     'pressure_in': 30.26,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 36,
#     'cloud': 0,
#     'feelslike_c': 24.2,
#     'feelslike_f': 75.6,
#     'windchill_c': 23.8,
#     'windchill_f': 74.8,
#     'heatindex_c': 24.2,
#     'heatindex_f': 75.6,
#     'dewpoint_c': 8.1,
#     'dewpoint_f': 46.6,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 5.9,
#     'gust_kph': 9.5,
#     'uv': 6.6,
#     'short_rad': 537.38,
#     'diff_rad': 81.24,
#     'dni': 811.11,
#     'gti': 279.83},
#    {'time_epoch': 1757354400,
#     'time': '2025-09-08 14:00',
#     'temp_c': 24.8,
#     'temp_f': 76.6,
#     'is_day': 1,
#     'condition': {'text': 'Sunny',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#      'code': 1000},
#     'wind_mph': 5.1,
#     'wind_kph': 8.3,
#     'wind_degree': 72,
#     'wind_dir': 'ENE',
#     'pressure_mb': 1024.0,
#     'pressure_in': 30.25,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 35,
#     'cloud': 0,
#     'feelslike_c': 24.9,
#     'feelslike_f': 76.8,
#     'windchill_c': 24.8,
#     'windchill_f': 76.6,
#     'heatindex_c': 24.9,
#     'heatindex_f': 76.8,
#     'dewpoint_c': 8.8,
#     'dewpoint_f': 47.8,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 5.9,
#     'gust_kph': 9.5,
#     'uv': 6.8,
#     'short_rad': 593.09,
#     'diff_rad': 84.9,
#     'dni': 1302.03,
#     'gti': 335.95},
#    {'time_epoch': 1757358000,
#     'time': '2025-09-08 15:00',
#     'temp_c': 25.5,
#     'temp_f': 77.9,
#     'is_day': 1,
#     'condition': {'text': 'Sunny',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#      'code': 1000},
#     'wind_mph': 4.7,
#     'wind_kph': 7.6,
#     'wind_degree': 69,
#     'wind_dir': 'ENE',
#     'pressure_mb': 1024.0,
#     'pressure_in': 30.23,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 35,
#     'cloud': 0,
#     'feelslike_c': 25.4,
#     'feelslike_f': 77.7,
#     'windchill_c': 25.5,
#     'windchill_f': 77.9,
#     'heatindex_c': 25.4,
#     'heatindex_f': 77.7,
#     'dewpoint_c': 9.1,
#     'dewpoint_f': 48.3,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 5.4,
#     'gust_kph': 8.7,
#     'uv': 5.8,
#     'short_rad': 849.88,
#     'diff_rad': 102.11,
#     'dni': 3822.92,
#     'gti': 613.92},
#    {'time_epoch': 1757361600,
#     'time': '2025-09-08 16:00',
#     'temp_c': 25.7,
#     'temp_f': 78.3,
#     'is_day': 1,
#     'condition': {'text': 'Sunny',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#      'code': 1000},
#     'wind_mph': 4.3,
#     'wind_kph': 6.8,
#     'wind_degree': 66,
#     'wind_dir': 'ENE',
#     'pressure_mb': 1023.0,
#     'pressure_in': 30.2,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 35,
#     'cloud': 0,
#     'feelslike_c': 25.6,
#     'feelslike_f': 78.1,
#     'windchill_c': 25.7,
#     'windchill_f': 78.3,
#     'heatindex_c': 25.6,
#     'heatindex_f': 78.1,
#     'dewpoint_c': 9.5,
#     'dewpoint_f': 49.1,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 4.9,
#     'gust_kph': 7.9,
#     'uv': 4.2,
#     'short_rad': 807.9,
#     'diff_rad': 99.83,
#     'dni': 0.0,
#     'gti': 106.46},
#    {'time_epoch': 1757365200,
#     'time': '2025-09-08 17:00',
#     'temp_c': 25.7,
#     'temp_f': 78.3,
#     'is_day': 1,
#     'condition': {'text': 'Sunny',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#      'code': 1000},
#     'wind_mph': 4.0,
#     'wind_kph': 6.5,
#     'wind_degree': 62,
#     'wind_dir': 'ENE',
#     'pressure_mb': 1022.0,
#     'pressure_in': 30.19,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 36,
#     'cloud': 0,
#     'feelslike_c': 25.6,
#     'feelslike_f': 78.1,
#     'windchill_c': 25.7,
#     'windchill_f': 78.3,
#     'heatindex_c': 25.6,
#     'heatindex_f': 78.1,
#     'dewpoint_c': 9.7,
#     'dewpoint_f': 49.5,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 4.6,
#     'gust_kph': 7.5,
#     'uv': 2.5,
#     'short_rad': 747.68,
#     'diff_rad': 96.47,
#     'dni': 0.0,
#     'gti': 102.17},
#    {'time_epoch': 1757368800,
#     'time': '2025-09-08 18:00',
#     'temp_c': 25.6,
#     'temp_f': 78.0,
#     'is_day': 1,
#     'condition': {'text': 'Sunny',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#      'code': 1000},
#     'wind_mph': 4.0,
#     'wind_kph': 6.5,
#     'wind_degree': 52,
#     'wind_dir': 'NE',
#     'pressure_mb': 1021.0,
#     'pressure_in': 30.16,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 37,
#     'cloud': 0,
#     'feelslike_c': 25.6,
#     'feelslike_f': 78.2,
#     'windchill_c': 25.6,
#     'windchill_f': 78.0,
#     'heatindex_c': 25.6,
#     'heatindex_f': 78.2,
#     'dewpoint_c': 10.0,
#     'dewpoint_f': 50.0,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 5.1,
#     'gust_kph': 8.2,
#     'uv': 1.1,
#     'short_rad': 672.45,
#     'diff_rad': 91.74,
#     'dni': 0.0,
#     'gti': 96.33},
#    {'time_epoch': 1757372400,
#     'time': '2025-09-08 19:00',
#     'temp_c': 23.1,
#     'temp_f': 73.6,
#     'is_day': 1,
#     'condition': {'text': 'Sunny',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#      'code': 1000},
#     'wind_mph': 3.4,
#     'wind_kph': 5.4,
#     'wind_degree': 33,
#     'wind_dir': 'NNE',
#     'pressure_mb': 1022.0,
#     'pressure_in': 30.17,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 41,
#     'cloud': 0,
#     'feelslike_c': 23.2,
#     'feelslike_f': 73.7,
#     'windchill_c': 23.1,
#     'windchill_f': 73.6,
#     'heatindex_c': 23.2,
#     'heatindex_f': 73.7,
#     'dewpoint_c': 11.1,
#     'dewpoint_f': 51.9,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 5.9,
#     'gust_kph': 9.5,
#     'uv': 0.3,
#     'short_rad': 586.59,
#     'diff_rad': 84.92,
#     'dni': 0.0,
#     'gti': 88.4},
#    {'time_epoch': 1757376000,
#     'time': '2025-09-08 20:00',
#     'temp_c': 21.5,
#     'temp_f': 70.7,
#     'is_day': 1,
#     'condition': {'text': 'Sunny',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#      'code': 1000},
#     'wind_mph': 3.6,
#     'wind_kph': 5.8,
#     'wind_degree': 28,
#     'wind_dir': 'NNE',
#     'pressure_mb': 1022.0,
#     'pressure_in': 30.18,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 45,
#     'cloud': 0,
#     'feelslike_c': 21.5,
#     'feelslike_f': 70.7,
#     'windchill_c': 21.5,
#     'windchill_f': 70.7,
#     'heatindex_c': 21.5,
#     'heatindex_f': 70.8,
#     'dewpoint_c': 8.5,
#     'dewpoint_f': 47.2,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 7.5,
#     'gust_kph': 12.1,
#     'uv': 0.0,
#     'short_rad': 497.74,
#     'diff_rad': 74.25,
#     'dni': 0.0,
#     'gti': 76.96},
#    {'time_epoch': 1757379600,
#     'time': '2025-09-08 21:00',
#     'temp_c': 20.3,
#     'temp_f': 68.5,
#     'is_day': 0,
#     'condition': {'text': 'Clear ',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#      'code': 1000},
#     'wind_mph': 4.3,
#     'wind_kph': 6.8,
#     'wind_degree': 36,
#     'wind_dir': 'NE',
#     'pressure_mb': 1022.0,
#     'pressure_in': 30.17,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 51,
#     'cloud': 4,
#     'feelslike_c': 20.3,
#     'feelslike_f': 68.5,
#     'windchill_c': 20.3,
#     'windchill_f': 68.5,
#     'heatindex_c': 20.3,
#     'heatindex_f': 68.5,
#     'dewpoint_c': 9.6,
#     'dewpoint_f': 49.2,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 8.9,
#     'gust_kph': 14.4,
#     'uv': 0,
#     'short_rad': 0,
#     'diff_rad': 0,
#     'dni': 0,
#     'gti': 0},
#    {'time_epoch': 1757383200,
#     'time': '2025-09-08 22:00',
#     'temp_c': 19.0,
#     'temp_f': 66.2,
#     'is_day': 0,
#     'condition': {'text': 'Clear ',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#      'code': 1000},
#     'wind_mph': 4.3,
#     'wind_kph': 6.8,
#     'wind_degree': 42,
#     'wind_dir': 'NE',
#     'pressure_mb': 1022.0,
#     'pressure_in': 30.19,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 56,
#     'cloud': 18,
#     'feelslike_c': 19.0,
#     'feelslike_f': 66.2,
#     'windchill_c': 19.0,
#     'windchill_f': 66.2,
#     'heatindex_c': 19.0,
#     'heatindex_f': 66.2,
#     'dewpoint_c': 10.2,
#     'dewpoint_f': 50.3,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 8.9,
#     'gust_kph': 14.4,
#     'uv': 0,
#     'short_rad': 0,
#     'diff_rad': 0,
#     'dni': 0,
#     'gti': 0},
#    {'time_epoch': 1757386800,
#     'time': '2025-09-08 23:00',
#     'temp_c': 18.1,
#     'temp_f': 64.6,
#     'is_day': 0,
#     'condition': {'text': 'Clear ',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#      'code': 1000},
#     'wind_mph': 4.5,
#     'wind_kph': 7.2,
#     'wind_degree': 35,
#     'wind_dir': 'NE',
#     'pressure_mb': 1023.0,
#     'pressure_in': 30.2,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 62,
#     'cloud': 0,
#     'feelslike_c': 18.1,
#     'feelslike_f': 64.6,
#     'windchill_c': 18.1,
#     'windchill_f': 64.6,
#     'heatindex_c': 18.1,
#     'heatindex_f': 64.6,
#     'dewpoint_c': 10.4,
#     'dewpoint_f': 50.7,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 9.4,
#     'gust_kph': 15.1,
#     'uv': 0,
#     'short_rad': 0,
#     'diff_rad': 0,
#     'dni': 0,
#     'gti': 0}]},
#  {'date': '2025-09-09',
#   'date_epoch': 1757376000,
#   'day': {'maxtemp_c': 27.7,
#    'maxtemp_f': 81.9,
#    'mintemp_c': 12.1,
#    'mintemp_f': 53.8,
#    'avgtemp_c': 19.8,
#    'avgtemp_f': 67.6,
#    'maxwind_mph': 4.5,
#    'maxwind_kph': 7.2,
#    'totalprecip_mm': 0.0,
#    'totalprecip_in': 0.0,
#    'totalsnow_cm': 0.0,
#    'avgvis_km': 10.0,
#    'avgvis_miles': 6.0,
#    'avghumidity': 55,
#    'daily_will_it_rain': 0,
#    'daily_chance_of_rain': 0,
#    'daily_will_it_snow': 0,
#    'daily_chance_of_snow': 0,
#    'condition': {'text': 'Sunny',
#     'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#     'code': 1000},
#    'uv': 1.5},
#   'astro': {'sunrise': '07:20 AM',
#    'sunset': '08:00 PM',
#    'moonrise': '08:59 PM',
#    'moonset': '09:26 AM',
#    'moon_phase': 'Waning Gibbous',
#    'moon_illumination': 98,
#    'is_moon_up': 0,
#    'is_sun_up': 1},
#   'hour': [{'time_epoch': 1757390400,
#     'time': '2025-09-09 00:00',
#     'temp_c': 17.2,
#     'temp_f': 63.0,
#     'is_day': 0,
#     'condition': {'text': 'Clear ',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#      'code': 1000},
#     'wind_mph': 4.3,
#     'wind_kph': 6.8,
#     'wind_degree': 36,
#     'wind_dir': 'NE',
#     'pressure_mb': 1022.0,
#     'pressure_in': 30.19,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 62,
#     'cloud': 0,
#     'feelslike_c': 17.2,
#     'feelslike_f': 63.0,
#     'windchill_c': 17.2,
#     'windchill_f': 63.0,
#     'heatindex_c': 17.2,
#     'heatindex_f': 63.0,
#     'dewpoint_c': 10.0,
#     'dewpoint_f': 49.9,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 8.9,
#     'gust_kph': 14.4,
#     'uv': 0,
#     'short_rad': 0,
#     'diff_rad': 0,
#     'dni': 0,
#     'gti': 0},
#    {'time_epoch': 1757394000,
#     'time': '2025-09-09 01:00',
#     'temp_c': 16.0,
#     'temp_f': 60.8,
#     'is_day': 0,
#     'condition': {'text': 'Clear ',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#      'code': 1000},
#     'wind_mph': 3.6,
#     'wind_kph': 5.8,
#     'wind_degree': 44,
#     'wind_dir': 'NE',
#     'pressure_mb': 1022.0,
#     'pressure_in': 30.17,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 65,
#     'cloud': 0,
#     'feelslike_c': 16.0,
#     'feelslike_f': 60.8,
#     'windchill_c': 16.0,
#     'windchill_f': 60.8,
#     'heatindex_c': 16.0,
#     'heatindex_f': 60.8,
#     'dewpoint_c': 9.8,
#     'dewpoint_f': 49.6,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 7.5,
#     'gust_kph': 12.1,
#     'uv': 0,
#     'short_rad': 0,
#     'diff_rad': 0,
#     'dni': 0,
#     'gti': 0},
#    {'time_epoch': 1757397600,
#     'time': '2025-09-09 02:00',
#     'temp_c': 14.9,
#     'temp_f': 58.9,
#     'is_day': 0,
#     'condition': {'text': 'Clear ',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#      'code': 1000},
#     'wind_mph': 3.4,
#     'wind_kph': 5.4,
#     'wind_degree': 60,
#     'wind_dir': 'ENE',
#     'pressure_mb': 1022.0,
#     'pressure_in': 30.18,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 71,
#     'cloud': 0,
#     'feelslike_c': 14.8,
#     'feelslike_f': 58.7,
#     'windchill_c': 14.8,
#     'windchill_f': 58.7,
#     'heatindex_c': 14.9,
#     'heatindex_f': 58.9,
#     'dewpoint_c': 9.5,
#     'dewpoint_f': 49.2,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 7.0,
#     'gust_kph': 11.3,
#     'uv': 0,
#     'short_rad': 0,
#     'diff_rad': 0,
#     'dni': 0,
#     'gti': 0},
#    {'time_epoch': 1757401200,
#     'time': '2025-09-09 03:00',
#     'temp_c': 14.1,
#     'temp_f': 57.5,
#     'is_day': 0,
#     'condition': {'text': 'Clear ',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#      'code': 1000},
#     'wind_mph': 3.4,
#     'wind_kph': 5.4,
#     'wind_degree': 59,
#     'wind_dir': 'ENE',
#     'pressure_mb': 1022.0,
#     'pressure_in': 30.18,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 72,
#     'cloud': 0,
#     'feelslike_c': 14.0,
#     'feelslike_f': 57.1,
#     'windchill_c': 14.0,
#     'windchill_f': 57.1,
#     'heatindex_c': 14.1,
#     'heatindex_f': 57.5,
#     'dewpoint_c': 8.8,
#     'dewpoint_f': 47.8,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 7.0,
#     'gust_kph': 11.3,
#     'uv': 0,
#     'short_rad': 0,
#     'diff_rad': 0,
#     'dni': 0,
#     'gti': 0},
#    {'time_epoch': 1757404800,
#     'time': '2025-09-09 04:00',
#     'temp_c': 13.5,
#     'temp_f': 56.3,
#     'is_day': 0,
#     'condition': {'text': 'Clear ',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#      'code': 1000},
#     'wind_mph': 3.1,
#     'wind_kph': 5.0,
#     'wind_degree': 56,
#     'wind_dir': 'ENE',
#     'pressure_mb': 1022.0,
#     'pressure_in': 30.18,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 72,
#     'cloud': 0,
#     'feelslike_c': 13.3,
#     'feelslike_f': 55.9,
#     'windchill_c': 13.3,
#     'windchill_f': 55.9,
#     'heatindex_c': 13.5,
#     'heatindex_f': 56.3,
#     'dewpoint_c': 8.4,
#     'dewpoint_f': 47.2,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 6.6,
#     'gust_kph': 10.6,
#     'uv': 0,
#     'short_rad': 0,
#     'diff_rad': 0,
#     'dni': 0,
#     'gti': 0},
#    {'time_epoch': 1757408400,
#     'time': '2025-09-09 05:00',
#     'temp_c': 13.0,
#     'temp_f': 55.4,
#     'is_day': 0,
#     'condition': {'text': 'Clear ',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#      'code': 1000},
#     'wind_mph': 3.6,
#     'wind_kph': 5.8,
#     'wind_degree': 65,
#     'wind_dir': 'ENE',
#     'pressure_mb': 1022.0,
#     'pressure_in': 30.19,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 72,
#     'cloud': 0,
#     'feelslike_c': 12.7,
#     'feelslike_f': 54.8,
#     'windchill_c': 12.7,
#     'windchill_f': 54.8,
#     'heatindex_c': 13.0,
#     'heatindex_f': 55.4,
#     'dewpoint_c': 8.1,
#     'dewpoint_f': 46.5,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 7.5,
#     'gust_kph': 12.1,
#     'uv': 0,
#     'short_rad': 0,
#     'diff_rad': 0,
#     'dni': 0,
#     'gti': 0},
#    {'time_epoch': 1757412000,
#     'time': '2025-09-09 06:00',
#     'temp_c': 12.7,
#     'temp_f': 54.8,
#     'is_day': 0,
#     'condition': {'text': 'Clear ',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#      'code': 1000},
#     'wind_mph': 3.6,
#     'wind_kph': 5.8,
#     'wind_degree': 67,
#     'wind_dir': 'ENE',
#     'pressure_mb': 1023.0,
#     'pressure_in': 30.2,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 71,
#     'cloud': 0,
#     'feelslike_c': 12.3,
#     'feelslike_f': 54.1,
#     'windchill_c': 12.3,
#     'windchill_f': 54.1,
#     'heatindex_c': 12.7,
#     'heatindex_f': 54.8,
#     'dewpoint_c': 7.5,
#     'dewpoint_f': 45.5,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 7.5,
#     'gust_kph': 12.1,
#     'uv': 0,
#     'short_rad': 0,
#     'diff_rad': 0,
#     'dni': 0,
#     'gti': 0},
#    {'time_epoch': 1757415600,
#     'time': '2025-09-09 07:00',
#     'temp_c': 12.4,
#     'temp_f': 54.3,
#     'is_day': 0,
#     'condition': {'text': 'Clear ',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#      'code': 1000},
#     'wind_mph': 3.6,
#     'wind_kph': 5.8,
#     'wind_degree': 75,
#     'wind_dir': 'ENE',
#     'pressure_mb': 1023.0,
#     'pressure_in': 30.2,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 71,
#     'cloud': 0,
#     'feelslike_c': 12.0,
#     'feelslike_f': 53.5,
#     'windchill_c': 12.0,
#     'windchill_f': 53.5,
#     'heatindex_c': 12.4,
#     'heatindex_f': 54.3,
#     'dewpoint_c': 7.2,
#     'dewpoint_f': 45.0,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 7.5,
#     'gust_kph': 12.1,
#     'uv': 0,
#     'short_rad': 0,
#     'diff_rad': 0,
#     'dni': 0,
#     'gti': 0},
#    {'time_epoch': 1757419200,
#     'time': '2025-09-09 08:00',
#     'temp_c': 14.9,
#     'temp_f': 58.9,
#     'is_day': 1,
#     'condition': {'text': 'Sunny',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#      'code': 1000},
#     'wind_mph': 3.4,
#     'wind_kph': 5.4,
#     'wind_degree': 59,
#     'wind_dir': 'ENE',
#     'pressure_mb': 1023.0,
#     'pressure_in': 30.21,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 71,
#     'cloud': 0,
#     'feelslike_c': 14.6,
#     'feelslike_f': 58.3,
#     'windchill_c': 14.6,
#     'windchill_f': 58.3,
#     'heatindex_c': 15.4,
#     'heatindex_f': 59.6,
#     'dewpoint_c': 6.9,
#     'dewpoint_f': 44.5,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 6.9,
#     'gust_kph': 11.1,
#     'uv': 0.1,
#     'short_rad': 2.96,
#     'diff_rad': 1.29,
#     'dni': 2.19,
#     'gti': 1.86},
#    {'time_epoch': 1757422800,
#     'time': '2025-09-09 09:00',
#     'temp_c': 17.6,
#     'temp_f': 63.6,
#     'is_day': 1,
#     'condition': {'text': 'Sunny',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#      'code': 1000},
#     'wind_mph': 3.8,
#     'wind_kph': 6.1,
#     'wind_degree': 76,
#     'wind_dir': 'ENE',
#     'pressure_mb': 1023.0,
#     'pressure_in': 30.2,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 58,
#     'cloud': 0,
#     'feelslike_c': 17.3,
#     'feelslike_f': 63.2,
#     'windchill_c': 17.3,
#     'windchill_f': 63.2,
#     'heatindex_c': 18.4,
#     'heatindex_f': 65.1,
#     'dewpoint_c': 8.8,
#     'dewpoint_f': 47.9,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 5.6,
#     'gust_kph': 9.0,
#     'uv': 0.6,
#     'short_rad': 171.08,
#     'diff_rad': 46.66,
#     'dni': 150.8,
#     'gti': 92.84},
#    {'time_epoch': 1757426400,
#     'time': '2025-09-09 10:00',
#     'temp_c': 20.2,
#     'temp_f': 68.4,
#     'is_day': 1,
#     'condition': {'text': 'Sunny',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#      'code': 1000},
#     'wind_mph': 3.8,
#     'wind_kph': 6.1,
#     'wind_degree': 88,
#     'wind_dir': 'E',
#     'pressure_mb': 1023.0,
#     'pressure_in': 30.2,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 52,
#     'cloud': 0,
#     'feelslike_c': 20.1,
#     'feelslike_f': 68.2,
#     'windchill_c': 20.1,
#     'windchill_f': 68.2,
#     'heatindex_c': 21.5,
#     'heatindex_f': 70.7,
#     'dewpoint_c': 9.8,
#     'dewpoint_f': 49.6,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 4.4,
#     'gust_kph': 7.1,
#     'uv': 1.7,
#     'short_rad': 274.16,
#     'diff_rad': 58.65,
#     'dni': 258.38,
#     'gti': 140.29},
#    {'time_epoch': 1757430000,
#     'time': '2025-09-09 11:00',
#     'temp_c': 22.3,
#     'temp_f': 72.1,
#     'is_day': 1,
#     'condition': {'text': 'Sunny',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#      'code': 1000},
#     'wind_mph': 4.0,
#     'wind_kph': 6.5,
#     'wind_degree': 92,
#     'wind_dir': 'E',
#     'pressure_mb': 1022.0,
#     'pressure_in': 30.19,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 46,
#     'cloud': 0,
#     'feelslike_c': 23.3,
#     'feelslike_f': 74.0,
#     'windchill_c': 22.2,
#     'windchill_f': 72.0,
#     'heatindex_c': 23.3,
#     'heatindex_f': 74.0,
#     'dewpoint_c': 10.7,
#     'dewpoint_f': 51.2,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 4.6,
#     'gust_kph': 7.5,
#     'uv': 3.1,
#     'short_rad': 372.26,
#     'diff_rad': 67.33,
#     'dni': 386.01,
#     'gti': 185.53},
#    {'time_epoch': 1757433600,
#     'time': '2025-09-09 12:00',
#     'temp_c': 23.6,
#     'temp_f': 74.5,
#     'is_day': 1,
#     'condition': {'text': 'Sunny',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#      'code': 1000},
#     'wind_mph': 4.0,
#     'wind_kph': 6.5,
#     'wind_degree': 98,
#     'wind_dir': 'E',
#     'pressure_mb': 1022.0,
#     'pressure_in': 30.17,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 43,
#     'cloud': 3,
#     'feelslike_c': 24.4,
#     'feelslike_f': 75.9,
#     'windchill_c': 23.6,
#     'windchill_f': 74.5,
#     'heatindex_c': 24.4,
#     'heatindex_f': 75.9,
#     'dewpoint_c': 10.8,
#     'dewpoint_f': 51.4,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 4.6,
#     'gust_kph': 7.5,
#     'uv': 4.7,
#     'short_rad': 459.7,
#     'diff_rad': 73.86,
#     'dni': 554.62,
#     'gti': 228.88},
#    {'time_epoch': 1757437200,
#     'time': '2025-09-09 13:00',
#     'temp_c': 24.7,
#     'temp_f': 76.4,
#     'is_day': 1,
#     'condition': {'text': 'Sunny',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#      'code': 1000},
#     'wind_mph': 3.1,
#     'wind_kph': 5.0,
#     'wind_degree': 113,
#     'wind_dir': 'ESE',
#     'pressure_mb': 1021.0,
#     'pressure_in': 30.16,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 41,
#     'cloud': 4,
#     'feelslike_c': 25.1,
#     'feelslike_f': 77.2,
#     'windchill_c': 24.7,
#     'windchill_f': 76.4,
#     'heatindex_c': 25.1,
#     'heatindex_f': 77.2,
#     'dewpoint_c': 10.8,
#     'dewpoint_f': 51.4,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 3.6,
#     'gust_kph': 5.8,
#     'uv': 5.6,
#     'short_rad': 532.56,
#     'diff_rad': 78.77,
#     'dni': 813.69,
#     'gti': 272.81},
#    {'time_epoch': 1757440800,
#     'time': '2025-09-09 14:00',
#     'temp_c': 25.7,
#     'temp_f': 78.2,
#     'is_day': 1,
#     'condition': {'text': 'Sunny',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#      'code': 1000},
#     'wind_mph': 1.8,
#     'wind_kph': 2.9,
#     'wind_degree': 141,
#     'wind_dir': 'SE',
#     'pressure_mb': 1021.0,
#     'pressure_in': 30.15,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 39,
#     'cloud': 6,
#     'feelslike_c': 25.9,
#     'feelslike_f': 78.6,
#     'windchill_c': 25.7,
#     'windchill_f': 78.2,
#     'heatindex_c': 25.9,
#     'heatindex_f': 78.6,
#     'dewpoint_c': 10.8,
#     'dewpoint_f': 51.5,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 2.1,
#     'gust_kph': 3.3,
#     'uv': 6.0,
#     'short_rad': 587.82,
#     'diff_rad': 82.5,
#     'dni': 1311.28,
#     'gti': 326.74},
#    {'time_epoch': 1757444400,
#     'time': '2025-09-09 15:00',
#     'temp_c': 26.4,
#     'temp_f': 79.6,
#     'is_day': 1,
#     'condition': {'text': 'Sunny',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#      'code': 1000},
#     'wind_mph': 0.7,
#     'wind_kph': 1.1,
#     'wind_degree': 202,
#     'wind_dir': 'SSW',
#     'pressure_mb': 1020.0,
#     'pressure_in': 30.12,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 39,
#     'cloud': 7,
#     'feelslike_c': 26.5,
#     'feelslike_f': 79.6,
#     'windchill_c': 26.4,
#     'windchill_f': 79.6,
#     'heatindex_c': 26.5,
#     'heatindex_f': 79.6,
#     'dewpoint_c': 11.8,
#     'dewpoint_f': 53.2,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 0.8,
#     'gust_kph': 1.3,
#     'uv': 5.7,
#     'short_rad': 840.3,
#     'diff_rad': 101.32,
#     'dni': 3880.16,
#     'gti': 594.54},
#    {'time_epoch': 1757448000,
#     'time': '2025-09-09 16:00',
#     'temp_c': 27.1,
#     'temp_f': 80.7,
#     'is_day': 1,
#     'condition': {'text': 'Sunny',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#      'code': 1000},
#     'wind_mph': 0.4,
#     'wind_kph': 0.7,
#     'wind_degree': 242,
#     'wind_dir': 'WSW',
#     'pressure_mb': 1020.0,
#     'pressure_in': 30.11,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 39,
#     'cloud': 8,
#     'feelslike_c': 27.0,
#     'feelslike_f': 80.6,
#     'windchill_c': 27.1,
#     'windchill_f': 80.7,
#     'heatindex_c': 27.0,
#     'heatindex_f': 80.6,
#     'dewpoint_c': 12.2,
#     'dewpoint_f': 54.0,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 0.5,
#     'gust_kph': 0.8,
#     'uv': 3.9,
#     'short_rad': 797.84,
#     'diff_rad': 99.72,
#     'dni': 0.0,
#     'gti': 106.15},
#    {'time_epoch': 1757451600,
#     'time': '2025-09-09 17:00',
#     'temp_c': 26.1,
#     'temp_f': 79.0,
#     'is_day': 1,
#     'condition': {'text': 'Sunny',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#      'code': 1000},
#     'wind_mph': 1.1,
#     'wind_kph': 1.8,
#     'wind_degree': 305,
#     'wind_dir': 'NW',
#     'pressure_mb': 1019.0,
#     'pressure_in': 30.1,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 40,
#     'cloud': 9,
#     'feelslike_c': 26.5,
#     'feelslike_f': 79.7,
#     'windchill_c': 26.1,
#     'windchill_f': 79.0,
#     'heatindex_c': 26.5,
#     'heatindex_f': 79.7,
#     'dewpoint_c': 12.7,
#     'dewpoint_f': 54.9,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 1.3,
#     'gust_kph': 2.1,
#     'uv': 2.3,
#     'short_rad': 737.7,
#     'diff_rad': 96.42,
#     'dni': 0.0,
#     'gti': 101.91},
#    {'time_epoch': 1757455200,
#     'time': '2025-09-09 18:00',
#     'temp_c': 25.0,
#     'temp_f': 77.0,
#     'is_day': 1,
#     'condition': {'text': 'Sunny',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#      'code': 1000},
#     'wind_mph': 1.6,
#     'wind_kph': 2.5,
#     'wind_degree': 0,
#     'wind_dir': 'N',
#     'pressure_mb': 1019.0,
#     'pressure_in': 30.09,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 44,
#     'cloud': 5,
#     'feelslike_c': 25.9,
#     'feelslike_f': 78.6,
#     'windchill_c': 25.0,
#     'windchill_f': 77.0,
#     'heatindex_c': 25.9,
#     'heatindex_f': 78.6,
#     'dewpoint_c': 12.0,
#     'dewpoint_f': 53.5,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 2.0,
#     'gust_kph': 3.2,
#     'uv': 1.0,
#     'short_rad': 662.61,
#     'diff_rad': 91.66,
#     'dni': 0.0,
#     'gti': 96.05},
#    {'time_epoch': 1757458800,
#     'time': '2025-09-09 19:00',
#     'temp_c': 23.8,
#     'temp_f': 74.8,
#     'is_day': 1,
#     'condition': {'text': 'Sunny',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#      'code': 1000},
#     'wind_mph': 4.3,
#     'wind_kph': 6.8,
#     'wind_degree': 26,
#     'wind_dir': 'NNE',
#     'pressure_mb': 1019.0,
#     'pressure_in': 30.09,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 46,
#     'cloud': 2,
#     'feelslike_c': 25.2,
#     'feelslike_f': 77.4,
#     'windchill_c': 23.8,
#     'windchill_f': 74.8,
#     'heatindex_c': 25.2,
#     'heatindex_f': 77.4,
#     'dewpoint_c': 11.6,
#     'dewpoint_f': 52.9,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 7.7,
#     'gust_kph': 12.4,
#     'uv': 0.3,
#     'short_rad': 577.04,
#     'diff_rad': 84.77,
#     'dni': 0.0,
#     'gti': 88.06},
#    {'time_epoch': 1757462400,
#     'time': '2025-09-09 20:00',
#     'temp_c': 22.5,
#     'temp_f': 72.5,
#     'is_day': 0,
#     'condition': {'text': 'Clear ',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#      'code': 1000},
#     'wind_mph': 4.5,
#     'wind_kph': 7.2,
#     'wind_degree': 41,
#     'wind_dir': 'NE',
#     'pressure_mb': 1019.0,
#     'pressure_in': 30.08,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 48,
#     'cloud': 0,
#     'feelslike_c': 23.7,
#     'feelslike_f': 74.6,
#     'windchill_c': 22.5,
#     'windchill_f': 72.5,
#     'heatindex_c': 23.7,
#     'heatindex_f': 74.6,
#     'dewpoint_c': 11.2,
#     'dewpoint_f': 52.2,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 9.4,
#     'gust_kph': 15.1,
#     'uv': 0,
#     'short_rad': 0,
#     'diff_rad': 0,
#     'dni': 0,
#     'gti': 0},
#    {'time_epoch': 1757466000,
#     'time': '2025-09-09 21:00',
#     'temp_c': 21.5,
#     'temp_f': 70.7,
#     'is_day': 0,
#     'condition': {'text': 'Clear ',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#      'code': 1000},
#     'wind_mph': 3.8,
#     'wind_kph': 6.1,
#     'wind_degree': 69,
#     'wind_dir': 'ENE',
#     'pressure_mb': 1019.0,
#     'pressure_in': 30.1,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 55,
#     'cloud': 13,
#     'feelslike_c': 21.5,
#     'feelslike_f': 70.7,
#     'windchill_c': 21.5,
#     'windchill_f': 70.7,
#     'heatindex_c': 22.3,
#     'heatindex_f': 72.2,
#     'dewpoint_c': 11.8,
#     'dewpoint_f': 53.3,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 8.0,
#     'gust_kph': 12.9,
#     'uv': 0,
#     'short_rad': 0,
#     'diff_rad': 0,
#     'dni': 0,
#     'gti': 0},
#    {'time_epoch': 1757469600,
#     'time': '2025-09-09 22:00',
#     'temp_c': 20.4,
#     'temp_f': 68.7,
#     'is_day': 0,
#     'condition': {'text': 'Clear ',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#      'code': 1000},
#     'wind_mph': 3.8,
#     'wind_kph': 6.1,
#     'wind_degree': 93,
#     'wind_dir': 'E',
#     'pressure_mb': 1020.0,
#     'pressure_in': 30.11,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 59,
#     'cloud': 19,
#     'feelslike_c': 20.4,
#     'feelslike_f': 68.7,
#     'windchill_c': 20.4,
#     'windchill_f': 68.7,
#     'heatindex_c': 20.8,
#     'heatindex_f': 69.4,
#     'dewpoint_c': 12.1,
#     'dewpoint_f': 53.8,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 8.0,
#     'gust_kph': 12.9,
#     'uv': 0,
#     'short_rad': 0,
#     'diff_rad': 0,
#     'dni': 0,
#     'gti': 0},
#    {'time_epoch': 1757473200,
#     'time': '2025-09-09 23:00',
#     'temp_c': 19.4,
#     'temp_f': 67.0,
#     'is_day': 0,
#     'condition': {'text': 'Clear ',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#      'code': 1000},
#     'wind_mph': 3.1,
#     'wind_kph': 5.0,
#     'wind_degree': 103,
#     'wind_dir': 'ESE',
#     'pressure_mb': 1019.0,
#     'pressure_in': 30.09,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 52,
#     'cloud': 5,
#     'feelslike_c': 19.4,
#     'feelslike_f': 67.0,
#     'windchill_c': 19.4,
#     'windchill_f': 67.0,
#     'heatindex_c': 19.6,
#     'heatindex_f': 67.3,
#     'dewpoint_c': 9.1,
#     'dewpoint_f': 48.4,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 6.6,
#     'gust_kph': 10.6,
#     'uv': 0,
#     'short_rad': 0,
#     'diff_rad': 0,
#     'dni': 0,
#     'gti': 0}]},
#  {'date': '2025-09-10',
#   'date_epoch': 1757462400,
#   'day': {'maxtemp_c': 25.8,
#    'maxtemp_f': 78.4,
#    'mintemp_c': 14.8,
#    'mintemp_f': 58.6,
#    'avgtemp_c': 20.5,
#    'avgtemp_f': 68.9,
#    'maxwind_mph': 5.1,
#    'maxwind_kph': 8.3,
#    'totalprecip_mm': 0.0,
#    'totalprecip_in': 0.0,
#    'totalsnow_cm': 0.0,
#    'avgvis_km': 10.0,
#    'avgvis_miles': 6.0,
#    'avghumidity': 63,
#    'daily_will_it_rain': 0,
#    'daily_chance_of_rain': 0,
#    'daily_will_it_snow': 0,
#    'daily_chance_of_snow': 0,
#    'condition': {'text': 'Cloudy ',
#     'icon': '//cdn.weatherapi.com/weather/64x64/day/119.png',
#     'code': 1006},
#    'uv': 1.7},
#   'astro': {'sunrise': '07:21 AM',
#    'sunset': '07:58 PM',
#    'moonrise': '09:29 PM',
#    'moonset': '10:40 AM',
#    'moon_phase': 'Waning Gibbous',
# ...
#     'wind_mph': 2.5,
#     'wind_kph': 4.0,
#     'wind_degree': 162,
#     'wind_dir': 'SSE',
#     'pressure_mb': 1022.0,
#     'pressure_in': 30.17,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 80,
#     'cloud': 71,
#     'feelslike_c': 15.4,
#     'feelslike_f': 59.8,
#     'windchill_c': 15.4,
#     'windchill_f': 59.8,
#     'heatindex_c': 15.3,
#     'heatindex_f': 59.6,
#     'dewpoint_c': 11.8,
#     'dewpoint_f': 53.2,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 5.2,
#     'gust_kph': 8.3,
#     'uv': 0,
#     'short_rad': 0,
#     'diff_rad': 0,
#     'dni': 0,
#     'gti': 0},
#    {'time_epoch': 1757505600,
#     'time': '2025-09-10 08:00',
#     'temp_c': 17.2,
#     'temp_f': 63.0,
#     'is_day': 1,
#     'condition': {'text': 'Overcast ',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png',
#      'code': 1009},
#     'wind_mph': 2.5,
#     'wind_kph': 4.0,
#     'wind_degree': 149,
#     'wind_dir': 'SSE',
#     'pressure_mb': 1022.0,
#     'pressure_in': 30.18,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 79,
#     'cloud': 94,
#     'feelslike_c': 17.3,
#     'feelslike_f': 63.1,
#     'windchill_c': 17.3,
#     'windchill_f': 63.1,
#     'heatindex_c': 17.7,
#     'heatindex_f': 63.9,
#     'dewpoint_c': 11.8,
#     'dewpoint_f': 53.2,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 5.0,
#     'gust_kph': 8.1,
#     'uv': 0.1,
#     'short_rad': 2.56,
#     'diff_rad': 1.22,
#     'dni': 1.77,
#     'gti': 1.66},
#    {'time_epoch': 1757509200,
#     'time': '2025-09-10 09:00',
#     'temp_c': 19.1,
#     'temp_f': 66.4,
#     'is_day': 1,
#     'condition': {'text': 'Overcast ',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png',
#      'code': 1009},
#     'wind_mph': 2.9,
#     'wind_kph': 4.7,
#     'wind_degree': 169,
#     'wind_dir': 'S',
#     'pressure_mb': 1022.0,
#     'pressure_in': 30.18,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 65,
#     'cloud': 86,
#     'feelslike_c': 19.2,
#     'feelslike_f': 66.5,
#     'windchill_c': 19.2,
#     'windchill_f': 66.5,
#     'heatindex_c': 20.0,
#     'heatindex_f': 68.1,
#     'dewpoint_c': 12.0,
#     'dewpoint_f': 53.6,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 4.2,
#     'gust_kph': 6.8,
#     'uv': 0.7,
#     'short_rad': 156.76,
#     'diff_rad': 49.3,
#     'dni': 130.79,
#     'gti': 87.77},
#    {'time_epoch': 1757512800,
#     'time': '2025-09-10 10:00',
#     'temp_c': 21.0,
#     'temp_f': 69.8,
#     'is_day': 1,
#     'condition': {'text': 'Overcast ',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png',
#      'code': 1009},
#     'wind_mph': 4.0,
#     'wind_kph': 6.5,
#     'wind_degree': 186,
#     'wind_dir': 'S',
#     'pressure_mb': 1022.0,
#     'pressure_in': 30.18,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 58,
#     'cloud': 82,
#     'feelslike_c': 21.0,
#     'feelslike_f': 69.9,
#     'windchill_c': 21.0,
#     'windchill_f': 69.9,
#     'heatindex_c': 22.4,
#     'heatindex_f': 72.3,
#     'dewpoint_c': 12.1,
#     'dewpoint_f': 53.8,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 4.7,
#     'gust_kph': 7.5,
#     'uv': 1.9,
#     'short_rad': 254.62,
#     'diff_rad': 63.54,
#     'dni': 230.12,
#     'gti': 133.82},
#    {'time_epoch': 1757516400,
#     'time': '2025-09-10 11:00',
#     'temp_c': 22.3,
#     'temp_f': 72.1,
#     'is_day': 1,
#     'condition': {'text': 'Cloudy ',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/119.png',
#      'code': 1006},
#     'wind_mph': 5.1,
#     'wind_kph': 8.3,
#     'wind_degree': 200,
#     'wind_dir': 'SSW',
#     'pressure_mb': 1022.0,
#     'pressure_in': 30.18,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 51,
#     'cloud': 78,
#     'feelslike_c': 23.7,
#     'feelslike_f': 74.7,
#     'windchill_c': 22.3,
#     'windchill_f': 72.1,
#     'heatindex_c': 23.7,
#     'heatindex_f': 74.7,
#     'dewpoint_c': 12.3,
#     'dewpoint_f': 54.1,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 5.9,
#     'gust_kph': 9.5,
#     'uv': 3.7,
#     'short_rad': 348.54,
#     'diff_rad': 73.84,
#     'dni': 349.55,
#     'gti': 177.5},
#    {'time_epoch': 1757520000,
#     'time': '2025-09-10 12:00',
#     'temp_c': 23.1,
#     'temp_f': 73.5,
#     'is_day': 1,
#     'condition': {'text': 'Cloudy ',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/119.png',
#      'code': 1006},
#     'wind_mph': 4.9,
#     'wind_kph': 7.9,
#     'wind_degree': 210,
#     'wind_dir': 'SSW',
#     'pressure_mb': 1022.0,
#     'pressure_in': 30.18,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 51,
#     'cloud': 74,
#     'feelslike_c': 24.4,
#     'feelslike_f': 76.0,
#     'windchill_c': 23.1,
#     'windchill_f': 73.5,
#     'heatindex_c': 24.4,
#     'heatindex_f': 76.0,
#     'dewpoint_c': 12.8,
#     'dewpoint_f': 55.1,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 5.7,
#     'gust_kph': 9.1,
#     'uv': 5.5,
#     'short_rad': 432.51,
#     'diff_rad': 81.67,
#     'dni': 507.52,
#     'gti': 218.97},
#    {'time_epoch': 1757523600,
#     'time': '2025-09-10 13:00',
#     'temp_c': 23.6,
#     'temp_f': 74.6,
#     'is_day': 1,
#     'condition': {'text': 'Cloudy ',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/119.png',
#      'code': 1006},
#     'wind_mph': 5.1,
#     'wind_kph': 8.3,
#     'wind_degree': 230,
#     'wind_dir': 'SW',
#     'pressure_mb': 1022.0,
#     'pressure_in': 30.18,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 51,
#     'cloud': 72,
#     'feelslike_c': 24.9,
#     'feelslike_f': 76.8,
#     'windchill_c': 23.6,
#     'windchill_f': 74.6,
#     'heatindex_c': 24.9,
#     'heatindex_f': 76.8,
#     'dewpoint_c': 13.1,
#     'dewpoint_f': 55.6,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 5.9,
#     'gust_kph': 9.5,
#     'uv': 6.7,
#     'short_rad': 502.53,
#     'diff_rad': 87.63,
#     'dni': 750.29,
#     'gti': 260.24},
#    {'time_epoch': 1757527200,
#     'time': '2025-09-10 14:00',
#     'temp_c': 24.3,
#     'temp_f': 75.8,
#     'is_day': 1,
#     'condition': {'text': 'Cloudy ',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/119.png',
#      'code': 1006},
#     'wind_mph': 4.7,
#     'wind_kph': 7.6,
#     'wind_degree': 242,
#     'wind_dir': 'WSW',
#     'pressure_mb': 1022.0,
#     'pressure_in': 30.18,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 51,
#     'cloud': 70,
#     'feelslike_c': 25.4,
#     'feelslike_f': 77.7,
#     'windchill_c': 24.3,
#     'windchill_f': 75.8,
#     'heatindex_c': 25.4,
#     'heatindex_f': 77.7,
#     'dewpoint_c': 13.4,
#     'dewpoint_f': 56.2,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 5.4,
#     'gust_kph': 8.7,
#     'uv': 7.0,
#     'short_rad': 555.86,
#     'diff_rad': 92.06,
#     'dni': 1219.28,
#     'gti': 309.57},
#    {'time_epoch': 1757530800,
#     'time': '2025-09-10 15:00',
#     'temp_c': 24.9,
#     'temp_f': 76.7,
#     'is_day': 1,
#     'condition': {'text': 'Cloudy ',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/119.png',
#      'code': 1006},
#     'wind_mph': 4.5,
#     'wind_kph': 7.2,
#     'wind_degree': 258,
#     'wind_dir': 'WSW',
#     'pressure_mb': 1021.0,
#     'pressure_in': 30.16,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 51,
#     'cloud': 44,
#     'feelslike_c': 25.8,
#     'feelslike_f': 78.4,
#     'windchill_c': 24.9,
#     'windchill_f': 76.7,
#     'heatindex_c': 25.8,
#     'heatindex_f': 78.4,
#     'dewpoint_c': 14.1,
#     'dewpoint_f': 57.3,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 5.1,
#     'gust_kph': 8.3,
#     'uv': 6.0,
#     'short_rad': 800.54,
#     'diff_rad': 114.31,
#     'dni': 3703.99,
#     'gti': 558.25},
#    {'time_epoch': 1757534400,
#     'time': '2025-09-10 16:00',
#     'temp_c': 25.3,
#     'temp_f': 77.6,
#     'is_day': 1,
#     'condition': {'text': 'Cloudy ',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/119.png',
#      'code': 1006},
#     'wind_mph': 4.0,
#     'wind_kph': 6.5,
#     'wind_degree': 268,
#     'wind_dir': 'W',
#     'pressure_mb': 1021.0,
#     'pressure_in': 30.15,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 50,
#     'cloud': 31,
#     'feelslike_c': 26.1,
#     'feelslike_f': 79.0,
#     'windchill_c': 25.3,
#     'windchill_f': 77.6,
#     'heatindex_c': 26.1,
#     'heatindex_f': 79.0,
#     'dewpoint_c': 14.4,
#     'dewpoint_f': 57.9,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 4.6,
#     'gust_kph': 7.5,
#     'uv': 4.4,
#     'short_rad': 759.76,
#     'diff_rad': 111.43,
#     'dni': 0.0,
#     'gti': 115.78},
#    {'time_epoch': 1757538000,
#     'time': '2025-09-10 17:00',
#     'temp_c': 25.0,
#     'temp_f': 76.9,
#     'is_day': 1,
#     'condition': {'text': 'Sunny',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#      'code': 1000},
#     'wind_mph': 3.8,
#     'wind_kph': 6.1,
#     'wind_degree': 278,
#     'wind_dir': 'W',
#     'pressure_mb': 1020.0,
#     'pressure_in': 30.14,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 50,
#     'cloud': 18,
#     'feelslike_c': 26.0,
#     'feelslike_f': 78.7,
#     'windchill_c': 25.0,
#     'windchill_f': 76.9,
#     'heatindex_c': 26.0,
#     'heatindex_f': 78.7,
#     'dewpoint_c': 14.7,
#     'dewpoint_f': 58.5,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 4.4,
#     'gust_kph': 7.1,
#     'uv': 2.4,
#     'short_rad': 702.0,
#     'diff_rad': 106.46,
#     'dni': 0.0,
#     'gti': 110.1},
#    {'time_epoch': 1757541600,
#     'time': '2025-09-10 18:00',
#     'temp_c': 24.5,
#     'temp_f': 76.1,
#     'is_day': 1,
#     'condition': {'text': 'Sunny',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#      'code': 1000},
#     'wind_mph': 2.9,
#     'wind_kph': 4.7,
#     'wind_degree': 284,
#     'wind_dir': 'WNW',
#     'pressure_mb': 1020.0,
#     'pressure_in': 30.13,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 54,
#     'cloud': 13,
#     'feelslike_c': 25.7,
#     'feelslike_f': 78.3,
#     'windchill_c': 24.5,
#     'windchill_f': 76.1,
#     'heatindex_c': 25.7,
#     'heatindex_f': 78.3,
#     'dewpoint_c': 14.7,
#     'dewpoint_f': 58.5,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 3.7,
#     'gust_kph': 5.9,
#     'uv': 1.1,
#     'short_rad': 629.66,
#     'diff_rad': 100.28,
#     'dni': 0.0,
#     'gti': 103.03},
#    {'time_epoch': 1757545200,
#     'time': '2025-09-10 19:00',
#     'temp_c': 23.9,
#     'temp_f': 75.1,
#     'is_day': 1,
#     'condition': {'text': 'Sunny',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#      'code': 1000},
#     'wind_mph': 0.7,
#     'wind_kph': 1.1,
#     'wind_degree': 2,
#     'wind_dir': 'N',
#     'pressure_mb': 1020.0,
#     'pressure_in': 30.13,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 56,
#     'cloud': 10,
#     'feelslike_c': 25.4,
#     'feelslike_f': 77.7,
#     'windchill_c': 23.9,
#     'windchill_f': 75.1,
#     'heatindex_c': 25.4,
#     'heatindex_f': 77.7,
#     'dewpoint_c': 14.7,
#     'dewpoint_f': 58.5,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 1.2,
#     'gust_kph': 1.9,
#     'uv': 0.3,
#     'short_rad': 547.31,
#     'diff_rad': 91.99,
#     'dni': 0.0,
#     'gti': 93.87},
#    {'time_epoch': 1757548800,
#     'time': '2025-09-10 20:00',
#     'temp_c': 23.1,
#     'temp_f': 73.7,
#     'is_day': 0,
#     'condition': {'text': 'Clear ',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#      'code': 1000},
#     'wind_mph': 1.6,
#     'wind_kph': 2.5,
#     'wind_degree': 89,
#     'wind_dir': 'E',
#     'pressure_mb': 1020.0,
#     'pressure_in': 30.12,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 58,
#     'cloud': 7,
#     'feelslike_c': 25.1,
#     'feelslike_f': 77.1,
#     'windchill_c': 23.1,
#     'windchill_f': 73.7,
#     'heatindex_c': 25.1,
#     'heatindex_f': 77.1,
#     'dewpoint_c': 14.7,
#     'dewpoint_f': 58.5,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 3.3,
#     'gust_kph': 5.3,
#     'uv': 0,
#     'short_rad': 0,
#     'diff_rad': 0,
#     'dni': 0,
#     'gti': 0},
#    {'time_epoch': 1757552400,
#     'time': '2025-09-10 21:00',
#     'temp_c': 22.5,
#     'temp_f': 72.5,
#     'is_day': 0,
#     'condition': {'text': 'Clear ',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#      'code': 1000},
#     'wind_mph': 1.3,
#     'wind_kph': 2.2,
#     'wind_degree': 104,
#     'wind_dir': 'ESE',
#     'pressure_mb': 1021.0,
#     'pressure_in': 30.14,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 64,
#     'cloud': 12,
#     'feelslike_c': 24.8,
#     'feelslike_f': 76.7,
#     'windchill_c': 22.5,
#     'windchill_f': 72.5,
#     'heatindex_c': 24.8,
#     'heatindex_f': 76.7,
#     'dewpoint_c': 15.1,
#     'dewpoint_f': 59.1,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 2.8,
#     'gust_kph': 4.5,
#     'uv': 0,
#     'short_rad': 0,
#     'diff_rad': 0,
#     'dni': 0,
#     'gti': 0},
#    {'time_epoch': 1757556000,
#     'time': '2025-09-10 22:00',
#     'temp_c': 21.1,
#     'temp_f': 70.1,
#     'is_day': 0,
#     'condition': {'text': 'Clear ',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#      'code': 1000},
#     'wind_mph': 2.7,
#     'wind_kph': 4.3,
#     'wind_degree': 150,
#     'wind_dir': 'SSE',
#     'pressure_mb': 1021.0,
#     'pressure_in': 30.15,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 66,
#     'cloud': 14,
#     'feelslike_c': 21.1,
#     'feelslike_f': 70.1,
#     'windchill_c': 21.1,
#     'windchill_f': 70.1,
#     'heatindex_c': 22.3,
#     'heatindex_f': 72.2,
#     'dewpoint_c': 15.3,
#     'dewpoint_f': 59.5,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 5.6,
#     'gust_kph': 9.1,
#     'uv': 0,
#     'short_rad': 0,
#     'diff_rad': 0,
#     'dni': 0,
#     'gti': 0},
#    {'time_epoch': 1757559600,
#     'time': '2025-09-10 23:00',
#     'temp_c': 20.5,
#     'temp_f': 69.0,
#     'is_day': 0,
#     'condition': {'text': 'Partly Cloudy ',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#      'code': 1003},
#     'wind_mph': 3.6,
#     'wind_kph': 5.8,
#     'wind_degree': 177,
#     'wind_dir': 'S',
#     'pressure_mb': 1020.0,
#     'pressure_in': 30.12,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 62,
#     'cloud': 26,
#     'feelslike_c': 20.5,
#     'feelslike_f': 69.0,
#     'windchill_c': 20.5,
#     'windchill_f': 69.0,
#     'heatindex_c': 21.9,
#     'heatindex_f': 71.4,
#     'dewpoint_c': 12.4,
#     'dewpoint_f': 54.4,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 7.5,
#     'gust_kph': 12.1,
#     'uv': 0,
#     'short_rad': 0,
#     'diff_rad': 0,
#     'dni': 0,
#     'gti': 0}]}]

# %%
forecast_3_days_summary = []
for day in forecast:
    forecast_3_days_summary.append(f"{day['date']}: High {day['day']['maxtemp_f']}F, Low {day['day']['mintemp_f']}F - {day['day']['condition']['text']}")

# %%
forecast_3_days_summary
# Out:
# ['2025-09-08: High 79.2F, Low 51.6F - Sunny',
#  '2025-09-09: High 81.9F, Low 53.8F - Sunny',
#  '2025-09-10: High 78.4F, Low 58.6F - Cloudy ']

# %%
forecast_3_days_summary = []
for day in forecast:
    date_obj = datetime.strptime(day['date'], '%Y-%m-%d')
    formatted_date = date_obj.strftime('%A, %B %#d')
    forecast_3_days_summary.append(f"{formatted_date}:  High {day['day']['maxtemp_f']}F / Low {day['day']['mintemp_f']}F - {day['day']['condition']['text']}")

forecast_3_days_summary
# Out:
# ['Monday, September 8:  High 79.2F / Low 51.6F - Sunny',
#  'Tuesday, September 9:  High 81.9F / Low 53.8F - Sunny',
#  'Wednesday, September 10:  High 78.4F / Low 58.6F - Cloudy ']

# %%
today = pd.Timestamp.now().strftime("%Y-%m-%d")

astronomy_url = f"{baseurl}astronomy.json?key={api_key}&q={city}&dt={today}"

# %%
def get_city_data(city, api_key):
    #get current weather/sunrise, sunset, moon phas
#get a forecast
#get some astronomical data 
#get anything else you want (challenge)

#build a summary for the city and save the summary into a dictinary
#build a dataframe from that info and save as a csv file 
w
